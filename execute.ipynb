# %%
# !streamlit run app.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://192.168.0.127:8501
#
# 2024-11-09 13:10:36.515 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:10:38.070 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:10:40.749 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:17:12.456 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:28:57.416 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:28:57.537 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:28:57.653 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:28:57.796 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:28:57.935 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:28:58.065 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:28:58.208 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:28:58.313 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:28:58.435 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:28:58.596 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:28:58.776 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:28:58.948 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:28:59.102 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:28:59.360 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:28:59.512 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:28:59.636 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:28:59.759 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:28:59.904 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:00.038 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:00.172 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:00.277 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:00.384 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:00.506 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:00.638 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:00.767 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:00.904 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:01.055 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:01.186 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:01.320 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:01.452 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:01.596 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:01.727 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:01.850 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:01.980 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:02.088 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:02.215 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:02.344 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:02.486 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:02.642 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:02.767 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:02.893 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:03.036 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:03.183 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:03.317 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:03.450 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:03.584 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:03.689 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:03.817 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:03.949 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:04.090 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:04.208 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:04.311 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:04.423 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:04.541 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:04.670 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:04.803 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:04.927 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:05.053 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:05.187 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:05.321 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:05.450 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:05.575 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:05.684 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:05.810 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:05.927 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:06.040 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:06.143 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:06.263 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:06.395 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:06.526 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:06.632 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:06.754 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:06.894 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:07.031 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:07.154 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:07.257 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:07.374 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:07.499 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:07.623 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:23.330 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:23.451 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:23.588 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:23.710 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:23.854 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:24.000 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:24.128 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:24.235 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:24.344 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:24.452 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:24.577 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:24.698 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:24.848 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:24.999 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:25.140 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:25.282 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:25.409 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:25.539 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:25.687 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:25.816 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:25.963 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:26.082 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:26.208 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:26.345 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:26.487 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:26.609 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:26.730 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:26.860 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:27.016 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:27.129 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:27.240 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:27.366 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:27.497 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:27.617 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:27.745 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:27.869 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:27.996 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:28.127 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:28.257 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:28.368 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:28.491 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:28.614 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:28.742 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:28.846 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:28.969 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:29.092 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:29.221 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:29.345 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:29.507 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:29.655 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:29.771 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:29.891 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:30.029 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:30.155 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:30.277 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:30.404 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:30.525 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:30.678 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:30.803 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:30.923 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:31.051 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:31.172 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:31.327 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:31.470 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:31.636 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:31.767 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:31.886 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:32.027 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:32.166 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:32.300 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:32.428 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:32.557 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:32.675 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:32.794 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:32.922 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:33.064 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:33.177 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:33.298 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:33.419 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:33.583 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:33.695 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:33.825 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:33.931 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:34.048 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:34.168 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:34.278 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:34.393 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:34.544 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:34.706 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:34.850 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:34.958 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:35.076 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:35.201 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:35.322 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:35.463 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:35.578 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:35.722 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:35.883 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:36.033 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:36.174 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:36.305 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:36.435 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:36.545 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:36.645 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:36.749 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:36.862 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:36.981 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:37.108 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:37.216 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:37.324 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:37.424 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:37.535 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:37.632 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:37.736 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:37.837 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:37.939 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:38.044 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:38.156 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:38.274 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:38.384 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:38.513 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:38.618 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:38.731 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:38.841 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:38.947 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:39.078 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:39.191 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:39.295 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:39.398 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:39.508 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:39.618 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:39.726 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:39.831 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:39.943 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:40.062 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:40.173 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:40.281 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:40.393 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:40.517 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:40.659 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:40.800 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:40.950 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:41.094 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:41.237 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:41.355 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:41.465 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:41.602 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:41.721 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:41.848 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:41.971 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:42.112 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:42.252 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:42.375 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:42.480 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:42.587 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:42.692 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:42.810 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:42.941 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:43.075 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:43.216 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:29:43.326 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:30:57.292 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:30:57.442 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:30:57.566 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:30:57.669 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:30:57.770 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:30:57.909 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:30:58.046 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:30:58.171 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:30:58.302 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:30:58.433 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:30:58.575 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:30:58.705 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:30:58.845 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:30:58.978 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:30:59.160 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:30:59.290 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:30:59.426 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:30:59.556 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:30:59.677 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:30:59.826 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:30:59.935 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:00.070 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:00.213 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:00.345 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:00.476 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:00.633 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:00.759 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:00.903 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:01.037 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:01.168 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:01.299 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:01.411 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:01.536 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:01.678 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:01.822 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:01.986 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:02.152 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:02.290 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:02.409 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:02.526 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:02.666 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:02.776 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:02.901 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:03.050 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:03.165 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:03.323 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:03.493 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:03.650 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:03.824 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:03.984 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:04.136 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:04.342 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:04.492 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:04.634 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:04.784 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:04.922 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:05.072 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:05.202 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:05.342 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:05.476 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:05.606 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:05.736 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:05.886 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:06.026 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:06.171 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:06.325 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:06.459 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:06.610 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:06.761 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:06.911 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:07.051 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:07.184 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:07.321 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# Task exception was never retrieved
# future: <Task finished name='Task-41682' coro=<WebSocketProtocol13.write_message.<locals>.wrapper() done, defined at /home/joelma/anaconda3/lib/python3.11/site-packages/tornado/websocket.py:1085> exception=WebSocketClosedError()>
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/tornado/websocket.py", line 1087, in wrapper
#     await fut
# tornado.iostream.StreamClosedError: Stream is closed
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/tornado/websocket.py", line 1089, in wrapper
#     raise WebSocketClosedError()
# tornado.websocket.WebSocketClosedError
# 2024-11-09 13:31:07.876 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:08.015 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:08.164 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:08.281 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:08.401 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:08.519 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:08.642 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:08.769 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:08.892 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:09.031 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:09.194 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:09.323 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:09.458 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:09.604 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:09.737 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:09.877 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:10.016 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:10.155 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:10.287 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:10.416 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:10.523 Please replace `st.experimental_rerun` with `st.rerun`.
#
# `st.experimental_rerun` will be removed after 2024-04-01.
# 2024-11-09 13:31:10.640 Please replace `st.experimental_rerun` with `st.rerun`.
#
# ...
#     registro_agenda.app()
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 966, in app
#     salvar_conflito_multicurso(conflito_key, "Conflito", cursos_envolvidos, day, time, professor)
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 860, in salvar_conflito_multicurso
#     cursos_existentes = set(conflitos_existentes[conflito_key]["Cursos"])
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: unhashable type: 'list'
# 2024-11-09 19:50:12.059 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/app.py", line 26, in <module>
#     registro_agenda.app()
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 967, in app
#     salvar_conflito_multicurso(conflito_key, "Conflito", cursos_envolvidos, day, time, professor)
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 859, in salvar_conflito_multicurso
#     cursos_existentes = set(conflitos_existentes[conflito_key]["Cursos"])
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: unhashable type: 'list'
# 2024-11-09 19:52:05.068 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/app.py", line 26, in <module>
#     registro_agenda.app()
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 965, in app
#     salvar_conflito_multicurso(conflito_key, "Conflito", cursos_envolvidos, day, time, professor)
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 859, in salvar_conflito_multicurso
#     cursos_existentes = set(conflitos_existentes[conflito_key]["Cursos"])
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: unhashable type: 'list'
# 2024-11-09 19:53:27.979 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/app.py", line 26, in <module>
#     registro_agenda.app()
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 967, in app
#     salvar_conflito_multicurso(conflito_key, "Conflito", cursos_envolvidos, day, time, professor)
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 859, in salvar_conflito_multicurso
#     cursos_existentes = set(conflitos_existentes[conflito_key]["Cursos"])
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: unhashable type: 'list'
# 2024-11-09 19:59:56.187 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/app.py", line 26, in <module>
#     registro_agenda.app()
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 967, in app
#     salvar_conflito_multicurso(conflito_key, "Conflito", cursos_envolvidos, day, time, professor)
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 859, in salvar_conflito_multicurso
#     cursos_existentes = set(conflitos_existentes[conflito_key]["Cursos"])
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: unhashable type: 'list'
# 2024-11-09 20:06:11.339 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/app.py", line 26, in <module>
#     registro_agenda.app()
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 969, in app
#     salvar_conflito_multicurso(conflito_key, "Conflito", cursos_envolvidos, day, time, professor)
# TypeError: app.<locals>.salvar_conflito_multicurso() missing 1 required positional argument: 'professor'
# 2024-11-09 20:15:37.226 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/app.py", line 26, in <module>
#     registro_agenda.app()
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 969, in app
#     salvar_conflito_multicurso(conflito_key, "Conflito", cursos_envolvidos, day, time, professor)
# TypeError: app.<locals>.salvar_conflito_multicurso() missing 1 required positional argument: 'professor'
# 2024-11-09 20:24:14.898 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/app.py", line 26, in <module>
#     registro_agenda.app()
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 959, in app
#     registrar_conflito(conflito_key, "Conflito", cursos_envolvidos, curso_selecionado, periodo_selecionado, day, time, professor)
# TypeError: app.<locals>.registrar_conflito() takes 7 positional arguments but 8 were given
# 2024-11-09 20:26:07.889 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/app.py", line 26, in <module>
#     registro_agenda.app()
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 959, in app
#     registrar_conflito(conflito_key, "Conflito", cursos_envolvidos, curso_selecionado, periodo_selecionado, day, time, professor)
# TypeError: app.<locals>.registrar_conflito() takes 7 positional arguments but 8 were given
# 2024-11-09 20:31:55.861 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/app.py", line 26, in <module>
#     registro_agenda.app()
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 961, in app
#     salvar_conflito_multicurso(conflito_key, "Conflito", cursos_envolvidos, day, time, professor)
# TypeError: app.<locals>.salvar_conflito_multicurso() missing 1 required positional argument: 'professor'
# 2024-11-09 20:34:00.468 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/app.py", line 26, in <module>
#     registro_agenda.app()
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 961, in app
#     salvar_conflito_multicurso(conflito_key, "Conflito", cursos_envolvidos, day, time, professor)
# TypeError: app.<locals>.salvar_conflito_multicurso() missing 2 required positional arguments: 'time' and 'professor'
# 2024-11-09 20:35:23.382 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/app.py", line 26, in <module>
#     registro_agenda.app()
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 961, in app
#     salvar_conflito_multicurso(conflito_key, "Conflito", cursos_envolvidos, curso_selecionado, day, time, professor)
# TypeError: app.<locals>.salvar_conflito_multicurso() missing 1 required positional argument: 'professor'
# 2024-11-09 20:51:03.273 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/app.py", line 26, in <module>
#     registro_agenda.app()
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 965, in app
#     salvar_conflito_multicurso(conflito_key, "Conflito", cursos_envolvidos, curso_selecionado, periodo_selecionado, day, time, professor)
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 844, in salvar_conflito_multicurso
#     nome_curso = curso.get("Curso")
#                  ^^^^^^^^^
# AttributeError: 'str' object has no attribute 'get'
# 2024-11-09 20:54:06.034 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/app.py", line 26, in <module>
#     registro_agenda.app()
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 965, in app
#     salvar_conflito_multicurso(conflito_key, "Conflito", cursos_envolvidos, curso_selecionado, periodo_selecionado, day, time, professor)
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 844, in salvar_conflito_multicurso
#     nome_curso = curso.get("Curso")
#                  ^^^^^^^^^
# AttributeError: 'str' object has no attribute 'get'
# 2024-11-09 20:55:36.579 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/app.py", line 26, in <module>
#     registro_agenda.app()
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 964, in app
#     salvar_conflito_multicurso(conflito_key, "Conflito", cursos_envolvidos, curso_selecionado, periodo_selecionado, day, time, professor)
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 843, in salvar_conflito_multicurso
#     nome_curso = curso.get("Curso")
#                  ^^^^^^^^^
# AttributeError: 'str' object has no attribute 'get'
# 2024-11-09 20:56:44.046 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/app.py", line 26, in <module>
#     registro_agenda.app()
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 965, in app
#     salvar_conflito_multicurso(conflito_key, "Conflito", cursos_envolvidos, curso_selecionado, periodo_selecionado, day, time, professor)
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 844, in salvar_conflito_multicurso
#     nome_curso = curso.get("Curso")
#                  ^^^^^^^^^
# AttributeError: 'str' object has no attribute 'get'
# 2024-11-09 21:02:10.250 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/app.py", line 26, in <module>
#     registro_agenda.app()
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 969, in app
#     salvar_conflito_multicurso(conflito_key, "Conflito", cursos_envolvidos, curso_selecionado, periodo_selecionado, day, time, professor)
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 839, in salvar_conflito_multicurso
#     caminho_arquivo = os.path.join(pasta_juncao, nome_arquivo)
#                                    ^^^^^^^^^^^^
# UnboundLocalError: cannot access local variable 'pasta_juncao' where it is not associated with a value
# 2024-11-09 21:03:18.184 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/app.py", line 26, in <module>
#     registro_agenda.app()
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 967, in app
#     salvar_conflito_multicurso(conflito_key, "Conflito", cursos_envolvidos, curso_selecionado, periodo_selecionado, day, time, professor)
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 867, in salvar_conflito_multicurso
#     conflitos_existentes.update(conflito)
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'list' object has no attribute 'update'
# 2024-11-09 21:05:33.307 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/app.py", line 26, in <module>
#     registro_agenda.app()
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 966, in app
#     salvar_conflito_multicurso(conflito_key, "Conflito", cursos_envolvidos, curso_selecionado, periodo_selecionado, day, time, professor)
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 866, in salvar_conflito_multicurso
#     conflitos_existentes.update(conflito)
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'list' object has no attribute 'update'
# 2024-11-09 21:34:32.759 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/app.py", line 26, in <module>
#     registro_agenda.app()
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 971, in app
#     salvar_conflito_multicurso(conflito_key, "Conflito", cursos_envolvidos, curso_selecionado, periodo_selecionado, day, time, professor)
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 860, in salvar_conflito_multicurso
#     conflito_existe = any(
#                       ^^^^
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 861, in <genexpr>
#     c.get("Dia") == conflito["Dia"] and
#                     ~~~~~~~~^^^^^^^
# KeyError: 'Dia'
# 2024-11-09 21:55:57.136 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/app.py", line 26, in <module>
#     registro_agenda.app()
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 975, in app
#     salvar_conflito_multicurso(conflito_key, "Conflito", cursos_envolvidos, curso_selecionado, periodo_selecionado, day, time, professor)
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 864, in salvar_conflito_multicurso
#     conflito_existe = any(
#                       ^^^^
#   File "/home/joelma/Downloads/projeto_horarios/registro_agenda.py", line 865, in <genexpr>
#     c.get("Dia") == conflito_data["Dia"] and
#     ^^^^^
# AttributeError: 'str' object has no attribute 'get'

# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /home/joelma/anaconda3/lib/python3.11/site-packages (0.21.0)

# %%
# !streamlit run conflito_entre_cursos.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://192.168.0.127:8501
#
# ^C
#   Stopping...

# %%
# !streamlit run download.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://192.168.0.127:8501
#
# 2024-10-26 09:43:41.848 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3790, in get_loc
#     return self._engine.get_loc(casted_key)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "index.pyx", line 152, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 181, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7080, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7088, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'Periodo'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/download.py", line 16, in <module>
#     periodo = row["Periodo"]
#               ~~~^^^^^^^^^^^
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/series.py", line 1040, in __getitem__
#     return self._get_value(key)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/series.py", line 1156, in _get_value
#     loc = self.index.get_loc(label)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3797, in get_loc
#     raise KeyError(key) from err
# KeyError: 'Periodo'
# /home/joelma/Downloads/projeto_horarios/download.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   disciplina = row["Disciplina"]
# 2024-10-26 09:53:52.131 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3790, in get_loc
#     return self._engine.get_loc(casted_key)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "index.pyx", line 152, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 181, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7080, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7088, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'Disciplina'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/download.py", line 41, in <module>
#     result_json = process_schedule(uploaded_file)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/joelma/Downloads/projeto_horarios/download.py", line 23, in process_schedule
#     "disciplina": row['Disciplina'],
#                   ~~~^^^^^^^^^^^^^^
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/series.py", line 1040, in __getitem__
#     return self._get_value(key)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/series.py", line 1156, in _get_value
#     loc = self.index.get_loc(label)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3797, in get_loc
#     raise KeyError(key) from err
# KeyError: 'Disciplina'
# 2024-10-26 09:58:44.451 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3790, in get_loc
#     return self._engine.get_loc(casted_key)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "index.pyx", line 152, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 181, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7080, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7088, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'A'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/download.py", line 45, in <module>
#     dados_json = processar_horarios(df)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/joelma/Downloads/projeto_horarios/download.py", line 11, in processar_horarios
#     if "Período" in str(row["A"]):
#                         ~~~^^^^^
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/series.py", line 1040, in __getitem__
#     return self._get_value(key)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/series.py", line 1156, in _get_value
#     loc = self.index.get_loc(label)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3797, in get_loc
#     raise KeyError(key) from err
# KeyError: 'A'
# 2024-10-26 10:00:08.933 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3790, in get_loc
#     return self._engine.get_loc(casted_key)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "index.pyx", line 152, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 181, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7080, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7088, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'A'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/download.py", line 27, in <module>
#     dados_json = processar_horarios(df)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/joelma/Downloads/projeto_horarios/download.py", line 11, in processar_horarios
#     if "Período" in str(row["A"]):
#                         ~~~^^^^^
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/series.py", line 1040, in __getitem__
#     return self._get_value(key)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/series.py", line 1156, in _get_value
#     loc = self.index.get_loc(label)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3797, in get_loc
#     raise KeyError(key) from err
# KeyError: 'A'
# /home/joelma/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# 2024-10-26 10:01:10.016 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column   with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# /home/joelma/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# 2024-10-26 10:03:27.809 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column   with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:15:36.017 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3790, in get_loc
#     return self._engine.get_loc(casted_key)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "index.pyx", line 152, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 181, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7080, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7088, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'horário'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/download.py", line 25, in <module>
#     df['horário'] = df['horário'].ffill()
#                     ~~^^^^^^^^^^^
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py", line 3896, in __getitem__
#     indexer = self.columns.get_loc(key)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3797, in get_loc
#     raise KeyError(key) from err
# KeyError: 'horário'
# /home/joelma/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# 2024-10-26 10:16:16.722 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column Terça with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:16:16.725 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3790, in get_loc
#     return self._engine.get_loc(casted_key)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "index.pyx", line 152, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 181, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7080, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7088, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'horário'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/download.py", line 26, in <module>
#     df['horário'] = df['horário'].ffill()
#                     ~~^^^^^^^^^^^
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py", line 3896, in __getitem__
#     indexer = self.columns.get_loc(key)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3797, in get_loc
#     raise KeyError(key) from err
# KeyError: 'horário'
# /home/joelma/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# 2024-10-26 10:16:52.829 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column Terça with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:16:52.842 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column Terça with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# /home/joelma/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# 2024-10-26 10:24:55.801 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column Terça with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:24:55.805 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column Terça with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# /home/joelma/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# 2024-10-26 10:25:42.037 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column Terça with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:25:42.042 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column Terça with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:37:23.535 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/download.py", line 31, in <module>
#     result = defaultdict(lambda: defaultdict(list))
#              ^^^^^^^^^^^
# NameError: name 'defaultdict' is not defined
# 2024-10-26 10:37:50.826 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/download.py", line 39, in <module>
#     periodo = entry["Período"]
#               ~~~~~^^^^^^^^^^^
# TypeError: string indices must be integers, not 'str'
# 2024-10-26 10:44:50.385 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/download.py", line 40, in <module>
#     periodo = entry["Período"]
#               ~~~~~^^^^^^^^^^^
# TypeError: string indices must be integers, not 'str'
# 2024-10-26 10:47:24.352 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/download.py", line 37, in <module>
#     for _, row in data.iterrows():
#                   ^^^^
# NameError: name 'data' is not defined
# /home/joelma/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# 2024-10-26 10:47:44.348 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 2 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:47:44.356 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 6 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:47:44.362 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 10 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:47:44.367 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 14 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:47:44.375 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 18 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:47:44.384 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 22 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:47:44.389 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 26 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:47:44.394 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 30 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:47:44.399 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 34 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:47:44.407 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 38 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:47:44.411 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 42 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:47:44.416 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 46 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:47:44.421 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 50 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:47:44.426 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 54 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:47:44.438 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 62 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:47:44.443 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 66 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:47:44.449 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 70 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:47:44.457 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 74 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:47:44.468 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 82 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:47:44.474 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 86 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:47:44.480 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 90 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:47:44.488 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 94 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# /home/joelma/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# 2024-10-26 10:49:26.488 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 2 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:49:26.501 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 6 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:49:26.513 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 10 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:49:26.527 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 14 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:49:26.539 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 18 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:49:26.553 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 22 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:49:26.567 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 26 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:49:26.580 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 30 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:49:26.592 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 34 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:49:26.606 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 38 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:49:26.621 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 42 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:49:26.633 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 46 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:49:26.646 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 50 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:49:26.665 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 54 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:49:26.703 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 62 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:49:26.718 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 66 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:49:26.732 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 70 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:49:26.744 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 74 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:49:26.771 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 82 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:49:26.788 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 86 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:49:26.799 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 90 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:49:26.811 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column 94 with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 10:50:46.652 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/download.py", line 38, in <module>
#     for _, row in data.iterrows():
#                   ^^^^
# NameError: name 'data' is not defined
# 2024-10-26 10:51:03.061 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/download.py", line 47, in <module>
#     if valor.isdigit():
#        ^^^^^^^^^^^^^
# AttributeError: 'int' object has no attribute 'isdigit'
# 2024-10-26 10:53:05.101 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/download.py", line 36, in <module>
#     for _, row in data.iterrows():
#                   ^^^^
# NameError: name 'data' is not defined
# /home/joelma/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# 2024-10-26 10:56:48.229 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column Terça with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# /home/joelma/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# 2024-10-26 11:04:44.372 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column Terça with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 11:04:44.375 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/download.py", line 23, in <module>
#     for period, period_df in df.groupby("Período"):
#                              ^^
# NameError: name 'df' is not defined
# 2024-10-26 11:05:17.187 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/download.py", line 14, in <module>
#     df['Horário'] = data['Horário'].ffill()
#                     ^^^^
# NameError: name 'data' is not defined
# /home/joelma/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# 2024-10-26 11:05:45.603 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column Terça with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# 2024-10-26 11:05:45.618 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3790, in get_loc
#     return self._engine.get_loc(casted_key)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "index.pyx", line 152, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 181, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7080, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7088, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'Informação'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/projeto_horarios/download.py", line 35, in <module>
#     info_key = row["Informação"].lower()
#                ~~~^^^^^^^^^^^^^^
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/series.py", line 1040, in __getitem__
#     return self._get_value(key)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/series.py", line 1156, in _get_value
#     loc = self.index.get_loc(label)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3797, in get_loc
#     raise KeyError(key) from err
# KeyError: 'Informação'
# /home/joelma/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# 2024-10-26 11:06:54.503 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column Terça with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# /home/joelma/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# 2024-10-26 11:17:23.151 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column Terça with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# /home/joelma/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# 2024-10-26 11:31:35.965 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column Terça with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# /home/joelma/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# 2024-10-26 11:33:16.383 Serialization of dataframe to Arrow table was unsuccessful due to: ("Expected bytes, got a 'int' object", 'Conversion failed for column Terça with type object'). Applying automatic fixes for column types to make the dataframe Arrow-compatible.
# ^C
#   Stopping...

# %%
# !streamlit run registro_agenda.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://192.168.0.127:8501
#
# 2024-10-24 19:57:42.903 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3790, in get_loc
#     return self._engine.get_loc(casted_key)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "index.pyx", line 152, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 181, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7080, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7088, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'id_curso'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/registro_agenda.py", line 173, in <module>
#     disciplinas_opcoes = disciplinas[disciplinas['id_curso'] == id_curso_selecionado]['nome_disciplina'].tolist()
#                                      ~~~~~~~~~~~^^^^^^^^^^^^
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py", line 3896, in __getitem__
#     indexer = self.columns.get_loc(key)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3797, in get_loc
#     raise KeyError(key) from err
# KeyError: 'id_curso'
# 2024-10-24 20:10:50.017 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/registro_agenda.py", line 170, in <module>
#     disciplinas = carregar_disciplinas(curso_selecionado)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/joelma/Downloads/registro_agenda.py", line 24, in carregar_disciplinas
#     with open(arquivo, 'r') as json_file:
#          ^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'disciplinas_administração.json'
# 2024-10-24 20:10:57.664 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3790, in get_loc
#     return self._engine.get_loc(casted_key)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "index.pyx", line 152, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 181, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7080, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7088, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'id_curso'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/registro_agenda.py", line 173, in <module>
#     disciplinas_opcoes = disciplinas[disciplinas['id_curso'] == id_curso_selecionado]['nome_disciplina'].tolist()
#                                      ~~~~~~~~~~~^^^^^^^^^^^^
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py", line 3896, in __getitem__
#     indexer = self.columns.get_loc(key)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3797, in get_loc
#     raise KeyError(key) from err
# KeyError: 'id_curso'
# 2024-10-24 20:11:00.536 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3790, in get_loc
#     return self._engine.get_loc(casted_key)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "index.pyx", line 152, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 181, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7080, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7088, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'id_curso'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/registro_agenda.py", line 173, in <module>
#     disciplinas_opcoes = disciplinas[disciplinas['id_curso'] == id_curso_selecionado]['nome_disciplina'].tolist()
#                                      ~~~~~~~~~~~^^^^^^^^^^^^
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py", line 3896, in __getitem__
#     indexer = self.columns.get_loc(key)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py", line 3797, in get_loc
#     raise KeyError(key) from err
# KeyError: 'id_curso'
# 2024-10-24 20:12:32.215 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/registro_agenda.py", line 170, in <module>
#     disciplinas = carregar_disciplinas(curso_selecionado)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/joelma/Downloads/registro_agenda.py", line 24, in carregar_disciplinas
#     with open(arquivo, 'r') as json_file:
#          ^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'disciplinas_análise_e_desenvolvimento_de_sistemas.json'
# 2024-10-24 20:24:06.741 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/registro_agenda.py", line 170, in <module>
#     disciplinas = carregar_disciplinas(curso_selecionado)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/joelma/Downloads/registro_agenda.py", line 24, in carregar_disciplinas
#     with open(arquivo, 'r') as json_file:
#          ^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'disciplinas_análise_e_desenvolvimento_de_sistemas.json'
# 2024-10-24 20:24:08.433 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/registro_agenda.py", line 170, in <module>
#     disciplinas = carregar_disciplinas(curso_selecionado)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/joelma/Downloads/registro_agenda.py", line 24, in carregar_disciplinas
#     with open(arquivo, 'r') as json_file:
#          ^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'disciplinas_banco_de_dados.json'
# 2024-10-24 20:24:10.182 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/registro_agenda.py", line 170, in <module>
#     disciplinas = carregar_disciplinas(curso_selecionado)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/joelma/Downloads/registro_agenda.py", line 24, in carregar_disciplinas
#     with open(arquivo, 'r') as json_file:
#          ^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'disciplinas_administração.json'
# 2024-10-24 20:24:22.751 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/registro_agenda.py", line 170, in <module>
#     disciplinas = carregar_disciplinas(curso_selecionado)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/joelma/Downloads/registro_agenda.py", line 24, in carregar_disciplinas
#     with open(arquivo, 'r') as json_file:
#          ^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'disciplinas_análise_e_desenvolvimento_de_sistemas.json'
# 2024-10-24 20:25:04.151 Uncaught app exception
# Traceback (most recent call last):
#   File "/home/joelma/anaconda3/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 589, in _run_script
#     exec(code, module.__dict__)
#   File "/home/joelma/Downloads/registro_agenda.py", line 170, in <module>
#     disciplinas = carregar_disciplinas(curso_selecionado)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/joelma/Downloads/registro_agenda.py", line 24, in carregar_disciplinas
#     with open(arquivo, 'r') as json_file:
#          ^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'disciplinas_banco_de_dados.json'
# ^C
#   Stopping...

# %%
#!pip install xlsxwriter

# %%
# !streamlit run registro_dados_comuns.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://192.168.0.127:8501
#
# ^C
#   Stopping...

# %%
# !streamlit run registro_matriz_curso.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://192.168.0.127:8501
#
# /home/joelma/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# /home/joelma/anaconda3/lib/python3.11/site-packages/pyarrow/pandas_compat.py:373: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
# ^C
#   Stopping...
